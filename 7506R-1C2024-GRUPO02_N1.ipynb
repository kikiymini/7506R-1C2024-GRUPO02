# %% [markdown]
# # <center>Organizaci&oacute;n de Datos</center>
# #### <center>C&aacute;tedra Ing. Rodriguez, Juan Manuel </center>
#
# ## <center>Trabajo Práctico 1</center>
# ### <center> Grupo 2</center>
# ##Integrantes:
# *   Aramayo Carolina
# *   Utrera Maximo Damian
# *   Villalba Ana Daniela
# *   Fiorilo Roy

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ORGA.DATOS RODRIGUEZ/Copia de properati_argentina_2021.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-cb11528a775b> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('/content/drive/MyDrive/ORGA.DATOS RODRIGUEZ/Copia de properati_argentina_2021.csv')
#       3 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
dfFiltrado =df[["place_l2","place_l3","property_type","property_currency","operation","property_title"]] # SELECCIONAMOS LAS COLUMNAS QUE VAMOS A UTILIZAR(SON LAS QUE MAS NOS SIRVEN PARA ENCONTRAR LOS DATOS QUE BUSCAMOS)
dfFiltrado
# Out:
#                         place_l2               place_l3    property_type  \
# 0                        Neuquén                    NaN             Casa
# 1                     Montevideo                    NaN             Casa
# 2                     Entre Ríos                    NaN             Casa
# 3                      Maldonado                    NaN             Casa
# 4                        Neuquén                    NaN               PH
# ...                          ...                    ...              ...
# 460149  Bs.As. G.B.A. Zona Oeste        Tres de Febrero  Local comercial
# 460150  Bs.As. G.B.A. Zona Norte     General San Martín  Local comercial
# 460151  Bs.As. G.B.A. Zona Norte     General San Martín  Local comercial
# 460152                  Santa Fe     Villa Constitución  Local comercial
# 460153                   Tucumán  San Miguel de Tucumán  Local comercial
#
#        property_currency operation  \
# 0                    NaN     Venta
# ...

# %%
dfFiltrado["property_currency"] = dfFiltrado["property_currency"].fillna(-1) # Filtramos las filas en las que el valor de la columna "property_currency" no sea igual a -1.
dfFiltrado = dfFiltrado[dfFiltrado["property_currency"] != -1]
dfFiltrado["operation"] = dfFiltrado["operation"].fillna(-1) # Filtramos las filas en las que el valor de la columna "property_currency" no sea igual a -1.
dfFiltrado = dfFiltrado[dfFiltrado["operation"] != -1]
dfFiltrado["property_type"] = dfFiltrado["property_type"].fillna(-1) # Filtramos las filas en las que el valor de la columna "property_type" no sea igual a -1.
dfFiltrado = dfFiltrado[dfFiltrado["property_type"] != -1]
dfFiltrado["place_l2"] = dfFiltrado["place_l2"].fillna(-1) # Filtramos las filas en las que el valor de la columna "place_l2" no sea igual a -1.
dfFiltrado = dfFiltrado[dfFiltrado["place_l2"] != -1]
#Basicamente lo que hice fue filtrar por todos los NaN que si son datos necesarios
dfFiltrado
# Out:
#                         place_l2               place_l3    property_type  \
# 1                     Montevideo                    NaN             Casa
# 2                     Entre Ríos                    NaN             Casa
# 3                      Maldonado                    NaN             Casa
# 4                        Neuquén                    NaN               PH
# 5                     Montevideo                    NaN     Departamento
# ...                          ...                    ...              ...
# 460148    Bs.As. G.B.A. Zona Sur        Lomas de Zamora  Local comercial
# 460149  Bs.As. G.B.A. Zona Oeste        Tres de Febrero  Local comercial
# 460150  Bs.As. G.B.A. Zona Norte     General San Martín  Local comercial
# 460151  Bs.As. G.B.A. Zona Norte     General San Martín  Local comercial
# 460153                   Tucumán  San Miguel de Tucumán  Local comercial
#
#        property_currency operation  \
# 1                    USD     Venta
# ...

# %%
dfFiltrado = dfFiltrado[dfFiltrado['property_currency'] == 'USD']
dfFiltrado = dfFiltrado[dfFiltrado['operation'] == 'Venta']
dfFiltrado = dfFiltrado[dfFiltrado['place_l2'] == 'Capital Federal']
valores_a_mantener = ['Casa', 'PH', 'Departamento']
dfFiltrado = dfFiltrado[dfFiltrado['property_type'].isin(valores_a_mantener)]
#Filtre por los valores que pide el enunciado USD, VENTA, CASA,PH, DEPARTAMENTO, CABA.
dfFiltrado
# Out:
#                place_l2              place_l3 property_type property_currency  \
# 25      Capital Federal                   NaN          Casa               USD
# 42      Capital Federal                  Boca  Departamento               USD
# 43      Capital Federal                  Boca  Departamento               USD
# 49      Capital Federal                  Once  Departamento               USD
# 51      Capital Federal                 Boedo            PH               USD
# ...                 ...                   ...           ...               ...
# 460072  Capital Federal      Villa del Parque  Departamento               USD
# 460073  Capital Federal      Villa del Parque  Departamento               USD
# 460074  Capital Federal      Villa del Parque  Departamento               USD
# 460075  Capital Federal      Villa del Parque  Departamento               USD
# 460090  Capital Federal  Centro / Microcentro  Departamento               USD
#
# ...

# %%
# @title property_type

from matplotlib import pyplot as plt
import seaborn as sns
dfFiltrado.groupby('property_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.xlabel("Precio en Dolares", fontsize=15)
plt.ylabel("Tipo de Propiedad", fontsize=15)
# Out:
# Text(0, 0.5, 'Tipo de Propiedad')
